# %%
from layers import TransformerEncoderLayer
import torch

# %%
v = torch.rand(10, 32, 64).to('cuda')
layer = TransformerEncoderLayer(d_model=64, nhead=8, norm_first=False, swiglu=True, rmsnorm=False).to('cuda')
out = layer(v)
print(out.shape)
# Out:
# after norm1: torch.Size([10, 32, 64])
# torch.Size([10, 32, 64])

# %%
from lib.layers.Encodings import sinusoidal_positional_encoding

# %%
a = sinusoidal_positional_encoding(10, 64, device='cuda')

# %%
a
# Out:
# tensor([[[ 0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#            1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,
#            0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00],
# ...
